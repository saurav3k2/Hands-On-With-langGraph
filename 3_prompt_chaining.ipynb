# %%
from langgraph.graph import StateGraph , START , END 
from langchain_groq import ChatGroq
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGroq(
    model = "llama-3.3-70b-versatile",
)

# %%
class BlogState(TypedDict):
    title : str
    outline :str
    content : str

# %%
def create_outline(state:BlogState) -> BlogState:
    
    # fetch titlee
    title=  state['title']
    
    # call llm gen outline
    prompt = f"Genrate a details for a blog on the topic - {title}"
    outline = model.invoke(prompt).content
    
    # update state
    state['outline']= outline
    
    return state

# %%
def create_blog(state: BlogState)  -> BlogState:
    title = state['title']
    outline = state['outline']
    
    prompt = f"Write a detailed blog on the title -{title} using the following outline\n {outline}"
    
    content = model.invoke(prompt).content
    state['content'] = content
    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': '**Title:** "The Rise of AI in India: Opportunities, Challenges, and the Future"\n\n**Introduction:**\nArtificial Intelligence (AI) has been transforming industries and revolutionizing the way we live and work. India, with its vast talent pool and growing economy, has emerged as a significant player in the global AI landscape. In this blog, we will explore the rise of AI in India, its current state, opportunities, challenges, and the future prospects.\n\n**Current State of AI in India:**\n\n1. **Government Initiatives:** The Indian government has launched several initiatives to promote AI adoption, such as the National AI Strategy, which aims to make India a global leader in AI by 2025.\n2. **Startups and Innovation:** India has seen a surge in AI startups, with many companies focusing on areas like natural language processing, computer vision, and machine learning.\n3. **Research and Development:** Indian institutions and research organizations are actively involved in AI research, with a focus on developing indigenous AI technologies.\n4. **Adoption in Industries:** AI is being adopted in various industries, including healthcare, finance, retail, and manufacturing, to improve efficiency, productivity, and decision-making.\n\n**Opportunities:**\n\n1. **Talent Pool:** India has a large pool of skilled professionals in AI and related fields, making it an attractive destination for companies looking to set up AI development centers.\n2. **Cost-Effective:** India offers a cost-effective solution for AI development, with lower labor costs and a favorable business environment.\n3. **Growing Demand:** The demand for AI solutions is growing rapidly in India, driven by the need for digital transformation and automation.\n4. **Export Opportunities:** India can leverage its AI expertise to export AI solutions and services to other countries, generating significant revenue.\n\n**Challenges:**\n\n1. **Infrastructure:** India\'s infrastructure, including data centers, networking, and storage, needs to be upgraded to support large-scale AI adoption.\n2. **Data Quality:** The quality of data in India is a significant concern, with many datasets being incomplete, inaccurate, or biased.\n3. **Regulatory Framework:** India needs a robust regulatory framework to govern AI development and deployment, ensuring transparency, accountability, and ethics.\n4. **Skill Gap:** While India has a large talent pool, there is a shortage of skilled professionals in AI and related fields, particularly in areas like deep learning and reinforcement learning.\n\n**Future Prospects:**\n\n1. **AI for Social Good:** AI can be used to address India\'s social and economic challenges, such as healthcare, education, and environmental sustainability.\n2. **Indigenous AI:** India can develop its own AI technologies, reducing dependence on foreign companies and promoting self-reliance.\n3. **Job Creation:** AI can create new job opportunities in areas like AI development, deployment, and maintenance, contributing to India\'s economic growth.\n4. **Global Leadership:** India can emerge as a global leader in AI, with the potential to influence AI development and deployment worldwide.\n\n**Conclusion:**\nThe rise of AI in India is a significant development, with opportunities for growth, innovation, and social impact. While there are challenges to be addressed, the future prospects are promising, with India poised to become a major player in the global AI landscape. As AI continues to evolve and transform industries, it is essential for India to stay ahead of the curve, investing in research, development, and talent to reap the benefits of AI and create a better future for its citizens.\n\n**Recommendations:**\n\n1. **Invest in AI Research and Development:** The government and private sector should invest in AI research and development to create indigenous AI technologies.\n2. **Develop AI Talent:** India should focus on developing  ...

# %%
print(final_state['outline'])
# Out:
# **Title:** "The Rise of AI in India: Opportunities, Challenges, and the Future"
#
# **Introduction:**
# Artificial Intelligence (AI) has been transforming industries and revolutionizing the way we live and work. India, with its vast talent pool and growing economy, has emerged as a significant player in the global AI landscape. In this blog, we will explore the rise of AI in India, its current state, opportunities, challenges, and the future prospects.
#
# **Current State of AI in India:**
#
# 1. **Government Initiatives:** The Indian government has launched several initiatives to promote AI adoption, such as the National AI Strategy, which aims to make India a global leader in AI by 2025.
# 2. **Startups and Innovation:** India has seen a surge in AI startups, with many companies focusing on areas like natural language processing, computer vision, and machine learning.
# 3. **Research and Development:** Indian institutions and research organizations are actively involved in AI research, with a focus on developing indigenous AI technologies.
# 4. **Adoption in Industries:** AI is being adopted in various industries, including healthcare, finance, retail, and manufacturing, to improve efficiency, productivity, and decision-making.
#
# **Opportunities:**
#
# 1. **Talent Pool:** India has a large pool of skilled professionals in AI and related fields, making it an attractive destination for companies looking to set up AI development centers.
# 2. **Cost-Effective:** India offers a cost-effective solution for AI development, with lower labor costs and a favorable business environment.
# 3. **Growing Demand:** The demand for AI solutions is growing rapidly in India, driven by the need for digital transformation and automation.
# 4. **Export Opportunities:** India can leverage its AI expertise to export AI solutions and services to other countries, generating significant revenue.
#
# **Challenges:**
#
# 1. **Infrastructure:** India's infrastructure, including data centers, networking, and storage, needs to be upgraded to support large-scale AI adoption.
# 2. **Data Quality:** The quality of data in India is a significant concern, with many datasets being incomplete, inaccurate, or biased.
# 3. **Regulatory Framework:** India needs a robust regulatory framework to govern AI development and deployment, ensuring transparency, accountability, and ethics.
# 4. **Skill Gap:** While India has a large talent pool, there is a shortage of skilled professionals in AI and related fields, particularly in areas like deep learning and reinforcement learning.
#
# **Future Prospects:**
#
# 1. **AI for Social Good:** AI can be used to address India's social and economic challenges, such as healthcare, education, and environmental sustainability.
# 2. **Indigenous AI:** India can develop its own AI technologies, reducing dependence on foreign companies and promoting self-reliance.
# 3. **Job Creation:** AI can create new job opportunities in areas like AI development, deployment, and maintenance, contributing to India's economic growth.
# 4. **Global Leadership:** India can emerge as a global leader in AI, with the potential to influence AI development and deployment worldwide.
#
# **Conclusion:**
# The rise of AI in India is a significant development, with opportunities for growth, innovation, and social impact. While there are challenges to be addressed, the future prospects are promising, with India poised to become a major player in the global AI landscape. As AI continues to evolve and transform industries, it is essential for India to stay ahead of the curve, investing in research, development, and talent to reap the benefits of AI and create a better future for its citizens.
#
# **Recommendations:**
#
# 1. **Invest in AI Research and Development:** The government and private sector should invest in AI research and development to create indigenous AI technologies.
# 2. **Develop AI Talent:** India should focus on developing AI talent, with programs for education, training, and skill development.
# 3. **Promote AI Adoption:** The government and industry should promote AI adoption, with initiatives to raise awareness, provide funding, and support startup innovation.
# 4. **Address Regulatory Challenges:** India should establish a robust regulatory framework to govern AI development and deployment, ensuring transparency, accountability, and ethics.
#
# **Key Statistics:**
#
# 1. **AI Market Size:** The Indian AI market is expected to reach $7.8 billion by 2025, growing at a CAGR of 33.5%.
# 2. **AI Jobs:** India is expected to create over 100,000 new AI jobs by 2025, with a significant increase in demand for AI professionals.
# 3. **AI Startups:** India has over 1,000 AI startups, with many companies focusing on areas like natural language processing, computer vision, and machine learning.
# 4. **AI Investment:** India has seen significant investment in AI, with over $1 billion invested in AI startups in 2020 alone.
#
# **Infographics:**
#
# 1. **AI Adoption in India:** An infographic showing the current state of AI adoption in India, including industries, applications, and benefits.
# 2. **AI Talent in India:** An infographic highlighting the availability of AI talent in India, including the number of professionals, skills, and education.
# 3. **AI Investment in India:** An infographic showing the investment in AI in India, including funding, startups, and research initiatives.
# 4. **AI Future in India:** An infographic depicting the future of AI in India, including opportunities, challenges, and prospects.
#
# This blog provides a comprehensive overview of the rise of AI in India, covering the current state, opportunities, challenges, and future prospects. With the increasing adoption of AI in various industries and the growing demand for AI solutions, India is poised to become a significant player in the global AI landscape.

# %%
print(final_state['content'])
# Out:
# **The Rise of AI in India: Opportunities, Challenges, and the Future**
#
# Artificial Intelligence (AI) has been transforming industries and revolutionizing the way we live and work. India, with its vast talent pool and growing economy, has emerged as a significant player in the global AI landscape. In this blog, we will explore the rise of AI in India, its current state, opportunities, challenges, and the future prospects.
#
# **Current State of AI in India**
#
# The Indian government has launched several initiatives to promote AI adoption, such as the National AI Strategy, which aims to make India a global leader in AI by 2025. The government has also established the National Institution for Transforming India (NITI) Aayog, which is responsible for developing and implementing AI policies.
#
# India has seen a surge in AI startups, with many companies focusing on areas like natural language processing, computer vision, and machine learning. Indian institutions and research organizations are actively involved in AI research, with a focus on developing indigenous AI technologies. AI is being adopted in various industries, including healthcare, finance, retail, and manufacturing, to improve efficiency, productivity, and decision-making.
#
# Some notable examples of AI adoption in India include:
#
# * **Healthcare:** AI-powered chatbots are being used to provide medical consultations and diagnose diseases.
# * **Finance:** AI-powered systems are being used to detect fraud and improve credit scoring.
# * **Retail:** AI-powered recommendation systems are being used to personalize customer experiences.
# * **Manufacturing:** AI-powered predictive maintenance is being used to improve equipment efficiency and reduce downtime.
#
# **Opportunities**
#
# India has a large pool of skilled professionals in AI and related fields, making it an attractive destination for companies looking to set up AI development centers. India offers a cost-effective solution for AI development, with lower labor costs and a favorable business environment. The demand for AI solutions is growing rapidly in India, driven by the need for digital transformation and automation.
#
# India can leverage its AI expertise to export AI solutions and services to other countries, generating significant revenue. According to a report by NASSCOM, the Indian IT industry is expected to reach $350 billion by 2025, with AI and data analytics being key drivers of growth.
#
# Some of the key opportunities for AI in India include:
#
# * **Talent Pool:** India has a large pool of skilled professionals in AI and related fields, making it an attractive destination for companies looking to set up AI development centers.
# * **Cost-Effective:** India offers a cost-effective solution for AI development, with lower labor costs and a favorable business environment.
# * **Growing Demand:** The demand for AI solutions is growing rapidly in India, driven by the need for digital transformation and automation.
# * **Export Opportunities:** India can leverage its AI expertise to export AI solutions and services to other countries, generating significant revenue.
#
# **Challenges**
#
# India's infrastructure, including data centers, networking, and storage, needs to be upgraded to support large-scale AI adoption. The quality of data in India is a significant concern, with many datasets being incomplete, inaccurate, or biased. India needs a robust regulatory framework to govern AI development and deployment, ensuring transparency, accountability, and ethics.
#
# While India has a large talent pool, there is a shortage of skilled professionals in AI and related fields, particularly in areas like deep learning and reinforcement learning. According to a report by Glassdoor, the average salary for an AI engineer in India is around $15,000 per month, which is lower than in other countries.
#
# Some of the key challenges for AI in India include:
#
# * **Infrastructure:** India's infrastructure, including data centers, networking, and storage, needs to be upgraded to support large-scale AI adoption.
# * **Data Quality:** The quality of data in India is a significant concern, with many datasets being incomplete, inaccurate, or biased.
# * **Regulatory Framework:** India needs a robust regulatory framework to govern AI development and deployment, ensuring transparency, accountability, and ethics.
# * **Skill Gap:** While India has a large talent pool, there is a shortage of skilled professionals in AI and related fields, particularly in areas like deep learning and reinforcement learning.
#
# **Future Prospects**
#
# AI can be used to address India's social and economic challenges, such as healthcare, education, and environmental sustainability. India can develop its own AI technologies, reducing dependence on foreign companies and promoting self-reliance. AI can create new job opportunities in areas like AI development, deployment, and maintenance, contributing to India's economic growth.
#
# India can emerge as a global leader in AI, with the potential to influence AI development and deployment worldwide. According to a report by McKinsey, India can create over 100,000 new AI jobs by 2025, with a significant increase in demand for AI professionals.
#
# Some of the key future prospects for AI in India include:
#
# * **AI for Social Good:** AI can be used to address India's social and economic challenges, such as healthcare, education, and environmental sustainability.
# * **Indigenous AI:** India can develop its own AI technologies, reducing dependence on foreign companies and promoting self-reliance.
# * **Job Creation:** AI can create new job opportunities in areas like AI development, deployment, and maintenance, contributing to India's economic growth.
# * **Global Leadership:** India can emerge as a global leader in AI, with the potential to influence AI development and deployment worldwide.
#
# **Conclusion**
#
# The rise of AI in India is a significant development, with opportunities for growth, innovation, and social impact. While there are challenges to be addressed, the future prospects are promising, with India poised to become a major player in the global AI landscape. As AI continues to evolve and transform industries, it is essential for India to stay ahead of the curve, investing in research, development, and talent to reap the benefits of AI and create a better future for its citizens.
#
# **Recommendations**
#
# To realize the full potential of AI in India, we recommend the following:
#
# * **Invest in AI Research and Development:** The government and private sector should invest in AI research and development to create indigenous AI technologies.
# * **Develop AI Talent:** India should focus on developing AI talent, with programs for education, training, and skill development.
# * **Promote AI Adoption:** The government and industry should promote AI adoption, with initiatives to raise awareness, provide funding, and support startup innovation.
# * **Address Regulatory Challenges:** India should establish a robust regulatory framework to govern AI development and deployment, ensuring transparency, accountability, and ethics.
#
# **Key Statistics**
#
# * **AI Market Size:** The Indian AI market is expected to reach $7.8 billion by 2025, growing at a CAGR of 33.5%.
# * **AI Jobs:** India is expected to create over 100,000 new AI jobs by 2025, with a significant increase in demand for AI professionals.
# * **AI Startups:** India has over 1,000 AI startups, with many companies focusing on areas like natural language processing, computer vision, and machine learning.
# * **AI Investment:** India has seen significant investment in AI, with over $1 billion invested in AI startups in 2020 alone.
#
# **Infographics**
#
# We have included the following infographics to provide a visual representation of the current state of AI in India:
#
# 1. **AI Adoption in India:** An infographic showing the current state of AI adoption in India, including industries, applications, and benefits.
# 2. **AI Talent in India:** An infographic highlighting the availability of AI talent in India, including the number of professionals, skills, and education.
# 3. **AI Investment in India:** An infographic showing the investment in AI in India, including funding, startups, and research initiatives.
# 4. **AI Future in India:** An infographic depicting the future of AI in India, including opportunities, challenges, and prospects.
#
# These infographics provide a comprehensive overview of the current state of AI in India and the future prospects for the industry.
